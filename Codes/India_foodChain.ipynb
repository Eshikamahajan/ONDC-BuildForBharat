# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
# sns.set_style("darkgrid")

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df=pd.read_csv("../Zomato/zomato_data1/zomato.csv", encoding='ISO-8859-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_country = pd.read_excel("../Zomato/zomato_data1/Country-Code.xlsx")
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 368.0+ bytes

# %%
merged_df = df.merge(df_country, on="Country Code")
merged_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
merged_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
merged_df = merged_df[['Restaurant ID', 'Restaurant Name','Country', 'Country Code', 'City', 'Address','Locality', 'Locality Verbose','Average Cost for two', 'Currency','Cuisines','Price range', 'Aggregate rating',  'Rating text','Votes','Longitude', 'Latitude', 'Has Table booking','Has Online delivery', 'Is delivering now', 'Switch to order menu','Rating color' ]]
merged_df.head()
# Out:
#    Restaurant ID         Restaurant Name      Country  Country Code  \
# 0        6317637        Le Petit Souffle  Phillipines           162
# 1        6304287        Izakaya Kikufuji  Phillipines           162
# 2        6300002  Heat - Edsa Shangri-La  Phillipines           162
# 3        6318506                    Ooma  Phillipines           162
# 4        6314302             Sambo Kojin  Phillipines           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# ...

# %%
merged_df['Country'].unique()
# Out:
# array(['Phillipines', 'Brazil', 'United States', 'Australia', 'Canada',
#        'Singapore', 'UAE', 'India', 'Indonesia', 'New Zealand',
#        'United Kingdom', 'Qatar', 'South Africa', 'Sri Lanka', 'Turkey'],
#       dtype=object)

# %%
India_merged_df=merged_df[merged_df['Country']=='India']
India_merged_df.head()
# Out:
#      Restaurant ID                        Restaurant Name Country  \
# 624        3400025                             Jahanpanah   India
# 625        3400341                    Rangrezz Restaurant   India
# 626        3400005                Time2Eat - Mama Chicken   India
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya   India
# 628        3400017                         Pinch Of Spice   India
#
#      Country Code  City                                            Address  \
# 624             1  Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 625             1  Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 626             1  Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra
# 627             1  Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...
# 628             1  Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...
#
#         Locality   Locality Verbose  Average Cost for two            Currency  \
# ...

# %%
India_merged_df.to_csv("Indian_zomato.csv")

# %%
Indian_df=pd.read_csv("../Zomato/Indian_zomato.csv", encoding='ISO-8859-1')
Indian_df.head(7)
# Out:
#    Unnamed: 0  Restaurant ID                        Restaurant Name Country  \
# 0         624        3400025                             Jahanpanah   India
# 1         625        3400341                    Rangrezz Restaurant   India
# 2         626        3400005                Time2Eat - Mama Chicken   India
# 3         627        3400021  Chokho Jeeman Marwari Jain Bhojanalya   India
# 4         628        3400017                         Pinch Of Spice   India
# 5         629        3400325                              MoMo Cafe   India
# 6         630        3400059                  Peshawri - ITC Mughal   India
#
#    Country Code  City                                            Address  \
# 0             1  Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 1             1  Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 2             1  Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra
# ...

# %%
Indian_df[Indian_df['Price range']==1]
price_range_stats = Indian_df.groupby('Price range')['Average Cost for two'].agg(['min', 'max'])

# Display the result
print(price_range_stats)


def get_price_range(Cost):
    
    if Cost>=0 and Cost<=450:
        return 1 
    elif Cost>=451 and Cost<=950:
        return 2
    elif Cost>=951 and Cost<=1500:
        return 3
    elif Cost>=1501 and Cost<=2000:
        return 4
    else:
        return 5
# Out:
#               min   max
# Price range
# 1               0   450
# 2             250   950
# 3             500  1950
# 4            1000  8000

# %%
Indian_df['Price range'] = Indian_df['Average Cost for two'].apply(get_price_range)
Indian_df.head(7)
# Out:
#    Unnamed: 0  Restaurant ID                        Restaurant Name Country  \
# 0         624        3400025                             Jahanpanah   India
# 1         625        3400341                    Rangrezz Restaurant   India
# 2         626        3400005                Time2Eat - Mama Chicken   India
# 3         627        3400021  Chokho Jeeman Marwari Jain Bhojanalya   India
# 4         628        3400017                         Pinch Of Spice   India
# 5         629        3400325                              MoMo Cafe   India
# 6         630        3400059                  Peshawri - ITC Mughal   India
#
#    Country Code  City                                            Address  \
# 0             1  Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 1             1  Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 2             1  Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra
# ...

# %%
# Indian_df.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)
Indian_df.drop(['ID','Country Code','Locality','Currency','Rating color','Switch to order menu'],axis=1,inplace=True)#df.drop(['C', 'D'], axis=1)

# %%
Indian_df.head(7)
# Out:
#    Restaurant ID                        Restaurant Name Country  City  \
# 0        3400025                             Jahanpanah   India  Agra
# 1        3400341                    Rangrezz Restaurant   India  Agra
# 2        3400005                Time2Eat - Mama Chicken   India  Agra
# 3        3400021  Chokho Jeeman Marwari Jain Bhojanalya   India  Agra
# 4        3400017                         Pinch Of Spice   India  Agra
# 5        3400325                              MoMo Cafe   India  Agra
# 6        3400059                  Peshawri - ITC Mughal   India  Agra
#
#                                              Address  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 2        Main Market, Sadar Bazaar, Agra Cantt, Agra
# 3  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...
# 4  23/453, Opposite Sanjay Cinema, Wazipura Road,...
# 5  Courtyard by Marriott Agra, Phase 2, Fatehabad...
# ...

# %%
import plotly.express as px

# %%
city_counts = Indian_df['City'].value_counts().reset_index()
city_counts
# Out:
#             City  count
# 0      New Delhi   5473
# 1        Gurgaon   1118
# 2          Noida   1080
# 3      Faridabad    251
# 4      Ghaziabad     25
# 5      Ahmedabad     21
# 6       Guwahati     21
# 7        Lucknow     21
# 8   Bhubaneshwar     21
# 9       Amritsar     21
# 10          Pune     20
# 11    Puducherry     20
# 12         Patna     20
# 13      Ludhiana     20
# 14        Ranchi     20
# 15         Surat     20
# 16      Vadodara     20
# 17        Nashik     20
# 18        Nagpur     20
# 19        Mysore     20
# 20        Mumbai     20
# 21      Varanasi     20
# 22     Mangalore     20
# 23          Agra     20
# 24         Kochi     20
# 25       Kolkata     20
# 26      Dehradun     20
# 27     Allahabad     20
# 28    Aurangabad     20
# 29     Bangalore     20
# 30        Bhopal     20
# 31       Chennai     20
# 32    Coimbatore     20
# 33           Goa     20
# 34        Indore     20
# 35        Jaipur     20
# 36        Kanpur     20
# ...

# %%
Cuisines=set(Indian_df['Cuisines'].tolist())
len(Cuisines)

def flat_list(list):
    flattened_cuisine_list = [Cuisines.strip() for Cuisines in Cuisines for Cuisines in Cuisines.split(',')] # getting a flattened list of cuisines
    flattened_cuisine_list=set(flattened_cuisine_list)
    #print(len(flattened_cuisine_list))
    return flattened_cuisine_list
# Out:
# 4642
# 90

# %%
# flattened_cuisine_list

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(flattened_cuisine_list))

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
def city_wise_df(city):
    name_df='df_'+str(city)
    name_df=Indian_df[Indian_df['City']==city]
    return name_df

def wordcloud(sample_list):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(sample_list))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
    
def flattened_list(sample_list):
    flattened_cuisine_list = [Cuisines.strip() for Cuisines in sample_list for Cuisines in Cuisines.split(',')] # getting a flattened list of cuisines
    flattened_cuisine_list=flattened_cuisine_list
    #print(len(flattened_cuisine_list))
    return flattened_cuisine_list

# %%
def avg_cost(df,Cuisine_to_search):
    print("\n")
    print("Searching for ",Cuisine_to_search)
    mask = df.Cuisines.apply(lambda x: Cuisine_to_search in x)
    df = df[mask]
    price_range_stats = df.groupby('City')['Average Cost for two'].agg(['min', 'max'])
#     print(type(price_range_stats))
    print("Min price",price_range_stats['min'].iloc[0])
    print("Max price",price_range_stats['max'].iloc[0])
    price_mean_stats = df.groupby('City')['Average Cost for two'].mean()
    print("Average price",price_mean_stats.values[0])
#     print(type(price_mean_stats))

# %%
Agra_df=city_wise_df('Agra')
Agra_df_cuisines_list=Agra_df['Cuisines'].tolist()
Agra_df_cuisines_list=flattened_list(Agra_df_cuisines_list)
wordcloud(Agra_df_cuisines_list)

# %%
Cuisine_to_Search='Mughlai'
avg_cost(Agra_df,Cuisine_to_Search) 

Cuisine_to_Search='North Indian'
avg_cost(Agra_df,Cuisine_to_Search) 

Cuisine_to_Search='Continental'
avg_cost(Agra_df,Cuisine_to_Search)
# Out:
# Searching for  Mughlai
# Min price 700
# Max price 3600
# Average price 1550.0
#
#
# Searching for  North Indian
# Min price 0
# Max price 3600
# Average price 1090.0
#
#
# Searching for  Continental
# Min price 0
# Max price 1500
# Average price 720.0

# %%
# city_counts = Indian_df['City'].value_counts().reset_index()
# city_counts.columns = ['City', 'Number of Restaurants']

# # Create a pie chart using Plotly Express
# fig = px.pie(city_counts, values='Number of Restaurants', names='City', title='Number of Restaurants in Each City')
# fig.show()

# %%
India_merged_df['City'].unique()
India_merged_df[(India_merged_df['City']=='Agra') & (India_merged_df['Is delivering now']=='Yes')]
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country, Country Code, City, Address, Locality, Locality Verbose, Average Cost for two, Currency, Cuisines, Price range, Aggregate rating, Rating text, Votes, Longitude, Latitude, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Rating color]
# Index: []
#
# [0 rows x 22 columns]

# %%
df['Cuisines'].iloc[:15]
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
# 5                                Chinese
# 6                        Asian, European
# 7     Seafood, Filipino, Asian, European
# 8                European, Asian, Indian
# 9                               Filipino
# 10                     Filipino, Mexican
# 11         American, Ice Cream, Desserts
# 12                     Filipino, Mexican
# 13                              Filipino
# 14                                Korean
# Name: Cuisines, dtype: object
